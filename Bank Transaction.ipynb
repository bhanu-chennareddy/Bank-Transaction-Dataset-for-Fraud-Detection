# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("bank_transactions_data_2.csv", delimiter=",")
data
# Out:
#      TransactionID AccountID  TransactionAmount      TransactionDate  \
# 0         TX000001   AC00128              14.09  2023-04-11 16:29:14
# 1         TX000002   AC00455             376.24  2023-06-27 16:44:19
# 2         TX000003   AC00019             126.29  2023-07-10 18:16:08
# 3         TX000004   AC00070             184.50  2023-05-05 16:32:11
# 4         TX000005   AC00411              13.45  2023-10-16 17:51:24
# ...            ...       ...                ...                  ...
# 2507      TX002508   AC00297             856.21  2023-04-26 17:09:36
# 2508      TX002509   AC00322             251.54  2023-03-22 17:36:48
# 2509      TX002510   AC00095              28.63  2023-08-21 17:08:50
# 2510      TX002511   AC00118             185.97  2023-02-24 16:24:46
# 2511      TX002512   AC00009             243.08  2023-02-14 16:21:23
#
#      TransactionType          Location DeviceID      IP Address MerchantID  \
# ...

# %%
top_earners = data.sort_values(by="TransactionAmount", ascending=False)
top_earners[['AccountID', 'TransactionAmount', 'CustomerAge', 'TransactionType', 'Channel']].head()
# Out:
#      AccountID  TransactionAmount  CustomerAge TransactionType Channel
# 653    AC00423            1919.11           30           Debit     ATM
# 1438   AC00179            1831.02           62          Credit  Online
# 340    AC00107            1830.00           55           Debit  Online
# 1634   AC00358            1762.28           24           Debit     ATM
# 2414   AC00028            1664.33           18           Debit  Branch

# %%
below_earners = data.sort_values(by="TransactionAmount", ascending=True)
below_earners[['AccountID', 'TransactionAmount', 'CustomerAge', 'TransactionType', 'Channel']].head()
# Out:
#      AccountID  TransactionAmount  CustomerAge TransactionType Channel
# 1354   AC00097               0.26           20           Debit  Online
# 2253   AC00236               0.32           39           Debit     ATM
# 2259   AC00324               0.45           34           Debit  Branch
# 1879   AC00460               0.84           52           Debit     ATM
# 929    AC00329               0.86           25           Debit     ATM
